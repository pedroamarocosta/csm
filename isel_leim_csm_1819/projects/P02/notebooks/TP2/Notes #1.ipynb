# %%
import numpy as np

p = np.random.rand(10)

p = p/np.sum(p)

print(p)

idx = np.argsort(p)

print(idx)

print(p[idx])

codes = []

#string um byte por char
#enviar bytes

a = (1,)

print(type(a))

b = (3,)

print(a+b)

s = [(i,) for i in range(10)]

print(s)

i0 = 2
i1 = 3

s[i0]=s[i0]+s[i1]

print(s)

s.remove(s[i1])

c = ['' for i in range(10)]

print(c)

c[i0] = '1' + c[i0]
c[i1] = '0' + c[i1]

print(c)

p[i0] = p[i0] + p[i1]
p = np.delete(p, i1)

print(p)


#sC =  [Vocab[i] for i in symbolSeq]

#ss = ''.join(sC)


#sL = np.fromfile('../Data/file.pdf', 'uint8')


#sLu = np.unique(sL)

#ps = np.array([np.sum(sL==i) for i in sLu])

#ps = ps/sum(ps)

import re

# b = re.findall('[01]{8}', ps)

#guardar 3 bits no inicio da seuqencia para descrever quanto bit stuffing é que fizemos na mensagem

#c = np.array([int(i,2) for i in b]).astype('uint8')

#tabela (simbolo/codigo)

#f = open('../Data/x.pt', 'wb')
#f.write(c)
#f.close()

c = np.array([132,11])

bb = [format(u, '08b') for u in c]

print(bb)

d = ''.join(bb)

print(d)
